# %%
from lab4_solution import generate_sample_pair
from lab4_solution import load_and_preprocess_data
from lab4_solution import calculate_idi_ratio
from tensorflow import keras
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
file_path = 'dataset/processed_kdd_cleaned.csv' 
X_train, X_test, y_train, y_test = load_and_preprocess_data(file_path)
sensitive_columns = ['age']  # Example sensitive column(s)
non_sensitive_columns = [col for col in X_test.columns if col not in sensitive_columns]
sample_a, sample_b = generate_sample_pair(X_test, sensitive_columns, non_sensitive_columns)
# Out:
# /Volumes/Dwika/ISE/ISE-solution/lab4/lab4_solution.py:44: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.5211561425822735' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sample_a[col] = np.clip(sample_a[col] + perturbation, min_val, max_val)
# /Volumes/Dwika/ISE/ISE-solution/lab4/lab4_solution.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.5211561425822735' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sample_b[col] = np.clip(sample_b[col] + perturbation, min_val, max_val)

# %%
sample_a.shape
# Out:
# (36,)

# %%
sample_b
# Out:
# age                                         29.000000
# workclass                                    5.521156
# industry                                    26.337592
# occupation                                  27.101283
# education                                   10.427418
# wage-per-hour                                0.000000
# enroll-in-edu-inst-last-wk                   2.000000
# marital-status                               4.171974
# major-industry                              21.493867
# major-occupation                             0.000000
# race                                         2.268570
# hispanic-origin                              0.479516
# sex                                          0.000000
# memner-union                                 1.086776
# reason-unemployment                          2.713841
# employment-status                            0.448404
# capital-gain                                 0.000000
# ...

# %%
file_path = 'dataset/processed_kdd_cleaned.csv'  # Dataset path
model_path = 'DNN/model_processed_kdd_cleaned.h5'  # Model path
X_train, X_test, y_train, y_test = load_and_preprocess_data(file_path)
model = keras.models.load_model(model_path)

    # 2. Define sensitive and non-sensitive columns
sensitive_columns = ['age']  # Example sensitive column(s)
on_sensitive_columns = [col for col in X_test.columns if col not in sensitive_columns]

    # 3. Calculate and print the Individual Discrimination Instance Ratio
idi_ratio1 = calculate_idi_ratio(model, X_test, sensitive_columns, non_sensitive_columns)
idi_ratio2 = calculate_idi_ratio(model, X_test, sensitive_columns, non_sensitive_columns)
idi_ratio3 = calculate_idi_ratio(model, X_test, sensitive_columns, non_sensitive_columns)
print(f"IDI Ratio: {idi_ratio1}")
print(f"IDI Ratio: {idi_ratio2}")
print(f"IDI Ratio: {idi_ratio3}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /Volumes/Dwika/ISE/ISE-solution/lab4/lab4_solution.py:44: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.200956976147885' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sample_a[col] = np.clip(sample_a[col] + perturbation, min_val, max_val)
# /Volumes/Dwika/ISE/ISE-solution/lab4/lab4_solution.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.200956976147885' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sample_b[col] = np.clip(sample_b[col] + perturbation, min_val, max_val)
# ...

# %%
print(f"IDI Ratio: {idi_ratio1}")
print(f"IDI Ratio: {idi_ratio2}")
print(f"IDI Ratio: {idi_ratio3}")
# Out:
# IDI Ratio: 0.122
# IDI Ratio: 0.106
# IDI Ratio: 0.13
