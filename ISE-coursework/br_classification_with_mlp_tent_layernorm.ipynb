# %%
import pandas as pd
import numpy as np
import re
import math
import os
import subprocess

# Text and feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer

# Evaluation and tuning
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_curve, auc)

# Classifier
from sklearn.naive_bayes import GaussianNB

# Text cleaning & stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import torch
import torch.nn
# Out:
# [nltk_data] Downloading package stopwords to /Users/dwika/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import simple_mlp
import TextDataset
import importlib
importlib.reload(simple_mlp)
# Out:
# <module 'simple_mlp' from '/Volumes/Dwika/ISE/ISE-solution/lab1/simple_mlp.py'>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Folder and filenames
folder_path = "datasets/"
filenames = ["caffe.csv", "incubator-mxnet.csv", "keras.csv", "pytorch.csv", "tensorflow.csv"]

# Dictionary to store class distributions
class_distributions = {}

# Read each file and compute the distribution of the 'class' column
for filename in filenames:
    file_path = os.path.join(folder_path, filename)
    df = pd.read_csv(file_path)
    class_counts = df['class'].value_counts().sort_index()
    class_distributions[filename] = class_counts

# Prepare data for combined bar plot
dataset_names = []
class_0_counts = []
class_1_counts = []

for filename in filenames:
    counts = class_distributions.get(filename, pd.Series([0, 0]))
    dataset_names.append(filename.replace(".csv", ""))
    class_0_counts.append(counts.get(0, 0))
    class_1_counts.append(counts.get(1, 0))

x = range(len(dataset_names))
width = 0.35

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

bars0 = ax.bar([i - width/2 for i in x], class_0_counts, width, label='Class 0', color='blue')
bars1 = ax.bar([i + width/2 for i in x], class_1_counts, width, label='Class 1', color='orange')

# Add counts on top of bars
for bar in bars0 + bars1:
    height = bar.get_height()
    ax.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Labeling
ax.set_xlabel("Dataset")
ax.set_ylabel("Count")
ax.set_title("Class Distribution per Dataset")
ax.set_xticks(x)
ax.set_xticklabels(dataset_names, rotation=15)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Seems data is imbalanced for all

# %%
from math import gcd

# %%
# Show the ratio of each class to figure out which is better for ratio of 0 and 1

for i in range(len(class_0_counts)):
    print(f"Dataset: {filenames[i]}, Ratio:{class_1_counts[i]/class_0_counts[i]}")
# Out:
# Dataset: caffe.csv, Ratio:0.13043478260869565
# Dataset: incubator-mxnet.csv, Ratio:0.14412416851441243
# Dataset: keras.csv, Ratio:0.25328330206378985
# Dataset: pytorch.csv, Ratio:0.1445966514459665
# Dataset: tensorflow.csv, Ratio:0.23038810900082576

# %% [markdown]
# ### We choose tensorflow for training despite having a lower ratio then pytorch it still has the largest dataset , and not a huge difference between keras and tensorflow

# %%
from torch.utils.data import random_split, DataLoader

# Step 1: Create the full dataset
full_dataset = TextDataset.TextDatasetTFIDF('datasets/tensorflow.csv')

# Step 2: Define train/val split sizes
val_ratio = 0.2
val_size = int(len(full_dataset) * val_ratio)
train_size = len(full_dataset) - val_size

# Step 3: Split the dataset
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Step 4: Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
# Out:
# Preprocessed DataFrame:
#                                                    text  sentiment
# 941  Graph_def is invalid at node u'ExpandDims': In...          0
# 297  stream_executor/platform/mutex.h doesn't compi...          0
# 271  [Perfomance]Dilated/Atrous Conv implementation...          1
# 774  Tensorflow 2.0 keras load_model does not resto...          0
# 420  Multiprocessing for input pipeline . I have as...          0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, accuracy_score
import helper

# %%
model = simple_mlp.MLPWithLayerNorm(input_dim=1000).to('cpu') 
criterion = nn.CrossEntropyLoss()  
optimizer = optim.Adam(model.parameters(), lr=1e-2) 
model
# Out:
# MLPWithLayerNorm(
#   (fc1): Linear(in_features=1000, out_features=64, bias=True)
#   (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
epochs=100* len(train_loader)
# ========== Training Loop ==========
for epoch in range(epochs):
    model.train()
    total_train_loss = 0

    for batch_X, batch_y in train_loader:
        batch_X=batch_X.to('cpu')
        batch_y=batch_y.to('cpu')
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
    print(f"Epoch {epoch} until {epochs}")
# Out:
# Epoch 0 until 3800
# Epoch 1 until 3800
# Epoch 2 until 3800
# Epoch 3 until 3800
# Epoch 4 until 3800
# Epoch 5 until 3800
# Epoch 6 until 3800
# Epoch 7 until 3800
# Epoch 8 until 3800
# Epoch 9 until 3800
# Epoch 10 until 3800
# Epoch 11 until 3800
# Epoch 12 until 3800
# Epoch 13 until 3800
# Epoch 14 until 3800
# Epoch 15 until 3800
# Epoch 16 until 3800
# Epoch 17 until 3800
# Epoch 18 until 3800
# Epoch 19 until 3800
# Epoch 20 until 3800
# Epoch 21 until 3800
# Epoch 22 until 3800
# Epoch 23 until 3800
# Epoch 24 until 3800
# Epoch 25 until 3800
# Epoch 26 until 3800
# Epoch 27 until 3800
# Epoch 28 until 3800
# Epoch 29 until 3800
# Epoch 30 until 3800
# Epoch 31 until 3800
# Epoch 32 until 3800
# Epoch 33 until 3800
# Epoch 34 until 3800
# Epoch 35 until 3800
# Epoch 36 until 3800
# Epoch 37 until 3800
# Epoch 38 until 3800
# Epoch 39 until 3800
# Epoch 40 until 3800
# Epoch 41 until 3800
# Epoch 42 until 3800
# Epoch 43 until 3800
# Epoch 44 until 3800
# Epoch 45 until 3800
# Epoch 46 until 3800
# Epoch 47 until 3800
# Epoch 48 until 3800
# Epoch 49 until 3800
# Epoch 50 until 3800
# Epoch 51 until 3800
# Epoch 52 until 3800
# Epoch 53 until 3800
# Epoch 54 until 3800
# Epoch 55 until 3800
# Epoch 56 until 3800
# Epoch 57 until 3800
# Epoch 58 until 3800
# Epoch 59 until 3800
# Epoch 60 until 3800
# Epoch 61 until 3800
# Epoch 62 until 3800
# Epoch 63 until 3800
# Epoch 64 until 3800
# Epoch 65 until 3800
# Epoch 66 until 3800
# Epoch 67 until 3800
# Epoch 68 until 3800
# Epoch 69 until 3800
# Epoch 70 until 3800
# Epoch 71 until 3800
# Epoch 72 until 3800
# Epoch 73 until 3800
# Epoch 74 until 3800
# Epoch 75 until 3800
# Epoch 76 until 3800
# Epoch 77 until 3800
# Epoch 78 until 3800
# Epoch 79 until 3800
# Epoch 80 until 3800
# Epoch 81 until 3800
# Epoch 82 until 3800
# Epoch 83 until 3800
# Epoch 84 until 3800
# Epoch 85 until 3800
# Epoch 86 until 3800
# Epoch 87 until 3800
# Epoch 88 until 3800
# Epoch 89 until 3800
# Epoch 90 until 3800
# Epoch 91 until 3800
# Epoch 92 until 3800
# Epoch 93 until 3800
# Epoch 94 until 3800
# Epoch 95 until 3800
# Epoch 96 until 3800
# Epoch 97 until 3800
# Epoch 98 until 3800
# Epoch 99 until 3800
# Epoch 100 until 3800
# Epoch 101 until 3800
# Epoch 102 until 3800
# Epoch 103 until 3800
# Epoch 104 until 3800
# Epoch 105 until 3800
# Epoch 106 until 3800
# Epoch 107 until 3800
# Epoch 108 until 3800
# Epoch 109 until 3800
# Epoch 110 until 3800
# Epoch 111 until 3800
# Epoch 112 until 3800
# Epoch 113 until 3800
# Epoch 114 until 3800
# Epoch 115 until 3800
# Epoch 116 until 3800
# Epoch 117 until 3800
# Epoch 118 until 3800
# Epoch 119 until 3800
# Epoch 120 until 3800
# Epoch 121 until 3800
# Epoch 122 until 3800
# Epoch 123 until 3800
# Epoch 124 until 3800
# Epoch 125 until 3800
# Epoch 126 until 3800
# Epoch 127 until 3800
# Epoch 128 until 3800
# Epoch 129 until 3800
# Epoch 130 until 3800
# Epoch 131 until 3800
# Epoch 132 until 3800
# Epoch 133 until 3800
# Epoch 134 until 3800
# Epoch 135 until 3800
# Epoch 136 until 3800
# Epoch 137 until 3800
# Epoch 138 until 3800
# Epoch 139 until 3800
# Epoch 140 until 3800
# Epoch 141 until 3800
# Epoch 142 until 3800
# Epoch 143 until 3800
# Epoch 144 until 3800
# Epoch 145 until 3800
# Epoch 146 until 3800
# Epoch 147 until 3800
# Epoch 148 until 3800
# Epoch 149 until 3800
# Epoch 150 until 3800
# Epoch 151 until 3800
# Epoch 152 until 3800
# Epoch 153 until 3800
# Epoch 154 until 3800
# Epoch 155 until 3800
# Epoch 156 until 3800
# Epoch 157 until 3800
# Epoch 158 until 3800
# Epoch 159 until 3800
# Epoch 160 until 3800
# Epoch 161 until 3800
# Epoch 162 until 3800
# Epoch 163 until 3800
# Epoch 164 until 3800
# Epoch 165 until 3800
# Epoch 166 until 3800
# Epoch 167 until 3800
# Epoch 168 until 3800
# Epoch 169 until 3800
# Epoch 170 until 3800
# Epoch 171 until 3800
# Epoch 172 until 3800
# Epoch 173 until 3800
# Epoch 174 until 3800
# Epoch 175 until 3800
# Epoch 176 until 3800
# Epoch 177 until 3800
# Epoch 178 until 3800
# Epoch 179 until 3800
# Epoch 180 until 3800
# Epoch 181 until 3800
# Epoch 182 until 3800
# Epoch 183 until 3800
# Epoch 184 until 3800
# Epoch 185 until 3800
# Epoch 186 until 3800
# Epoch 187 until 3800
# Epoch 188 until 3800
# Epoch 189 until 3800
# Epoch 190 until 3800
# Epoch 191 until 3800
# Epoch 192 until 3800
# Epoch 193 until 3800
# Epoch 194 until 3800
# Epoch 195 until 3800
# Epoch 196 until 3800
# Epoch 197 until 3800
# Epoch 198 until 3800
# Epoch 199 until 3800
# Epoch 200 until 3800
# Epoch 201 until 3800
# Epoch 202 until 3800
# Epoch 203 until 3800
# Epoch 204 until 3800
# Epoch 205 until 3800
# Epoch 206 until 3800
# Epoch 207 until 3800
# Epoch 208 until 3800
# Epoch 209 until 3800
# Epoch 210 until 3800
# Epoch 211 until 3800
# Epoch 212 until 3800
# Epoch 213 until 3800
# Epoch 214 until 3800
# Epoch 215 until 3800
# Epoch 216 until 3800
# Epoch 217 until 3800
# Epoch 218 until 3800
# Epoch 219 until 3800
# Epoch 220 until 3800
# Epoch 221 until 3800
# Epoch 222 until 3800
# Epoch 223 until 3800
# Epoch 224 until 3800
# Epoch 225 until 3800
# Epoch 226 until 3800
# Epoch 227 until 3800
# Epoch 228 until 3800
# Epoch 229 until 3800
# Epoch 230 until 3800
# Epoch 231 until 3800
# Epoch 232 until 3800
# Epoch 233 until 3800
# Epoch 234 until 3800
# Epoch 235 until 3800
# Epoch 236 until 3800
# Epoch 237 until 3800
# Epoch 238 until 3800
# Epoch 239 until 3800
# Epoch 240 until 3800
# Epoch 241 until 3800
# Epoch 242 until 3800
# Epoch 243 until 3800
# Epoch 244 until 3800
# Epoch 245 until 3800
# Epoch 246 until 3800
# Epoch 247 until 3800
# Epoch 248 until 3800
# Epoch 249 until 3800
# Epoch 250 until 3800
# Epoch 251 until 3800
# Epoch 252 until 3800
# Epoch 253 until 3800
# Epoch 254 until 3800
# Epoch 255 until 3800
# Epoch 256 until 3800
# Epoch 257 until 3800
# Epoch 258 until 3800
# Epoch 259 until 3800
# Epoch 260 until 3800
# Epoch 261 until 3800
# Epoch 262 until 3800
# Epoch 263 until 3800
# Epoch 264 until 3800
# Epoch 265 until 3800
# Epoch 266 until 3800
# Epoch 267 until 3800
# Epoch 268 until 3800
# Epoch 269 until 3800
# Epoch 270 until 3800
# Epoch 271 until 3800
# Epoch 272 until 3800
# Epoch 273 until 3800
# Epoch 274 until 3800
# Epoch 275 until 3800
# Epoch 276 until 3800
# Epoch 277 until 3800
# Epoch 278 until 3800
# Epoch 279 until 3800
# Epoch 280 until 3800
# Epoch 281 until 3800
# Epoch 282 until 3800
# Epoch 283 until 3800
# Epoch 284 until 3800
# Epoch 285 until 3800
# Epoch 286 until 3800
# Epoch 287 until 3800
# Epoch 288 until 3800
# Epoch 289 until 3800
# Epoch 290 until 3800
# Epoch 291 until 3800
# Epoch 292 until 3800
# Epoch 293 until 3800
# Epoch 294 until 3800
# Epoch 295 until 3800
# Epoch 296 until 3800
# Epoch 297 until 3800
# Epoch 298 until 3800
# Epoch 299 until 3800
# Epoch 300 until 3800
# Epoch 301 until 3800
# Epoch 302 until 3800
# Epoch 303 until 3800
# Epoch 304 until 3800
# Epoch 305 until 3800
# Epoch 306 until 3800
# Epoch 307 until 3800
# Epoch 308 until 3800
# Epoch 309 until 3800
# Epoch 310 until 3800
# Epoch 311 until 3800
# Epoch 312 until 3800
# Epoch 313 until 3800
# Epoch 314 until 3800
# Epoch 315 until 3800
# Epoch 316 until 3800
# Epoch 317 until 3800
# Epoch 318 until 3800
# Epoch 319 until 3800
# Epoch 320 until 3800
# Epoch 321 until 3800
# Epoch 322 until 3800
# Epoch 323 until 3800
# Epoch 324 until 3800
# Epoch 325 until 3800
# Epoch 326 until 3800
# Epoch 327 until 3800
# Epoch 328 until 3800
# Epoch 329 until 3800
# Epoch 330 until 3800
# Epoch 331 until 3800
# Epoch 332 until 3800
# Epoch 333 until 3800
# Epoch 334 until 3800
# Epoch 335 until 3800
# Epoch 336 until 3800
# Epoch 337 until 3800
# Epoch 338 until 3800
# Epoch 339 until 3800
# Epoch 340 until 3800
# Epoch 341 until 3800
# Epoch 342 until 3800
# Epoch 343 until 3800
# Epoch 344 until 3800
# Epoch 345 until 3800
# Epoch 346 until 3800
# Epoch 347 until 3800
# Epoch 348 until 3800
# Epoch 349 until 3800
# Epoch 350 until 3800
# Epoch 351 until 3800
# Epoch 352 until 3800
# Epoch 353 until 3800
# Epoch 354 until 3800
# Epoch 355 until 3800
# Epoch 356 until 3800
# Epoch 357 until 3800
# Epoch 358 until 3800
# Epoch 359 until 3800
# Epoch 360 until 3800
# Epoch 361 until 3800
# Epoch 362 until 3800
# Epoch 363 until 3800
# Epoch 364 until 3800
# Epoch 365 until 3800
# Epoch 366 until 3800
# Epoch 367 until 3800
# Epoch 368 until 3800
# Epoch 369 until 3800
# Epoch 370 until 3800
# Epoch 371 until 3800
# Epoch 372 until 3800
# Epoch 373 until 3800
# Epoch 374 until 3800
# Epoch 375 until 3800
# Epoch 376 until 3800
# Epoch 377 until 3800
# Epoch 378 until 3800
# Epoch 379 until 3800
# Epoch 380 until 3800
# Epoch 381 until 3800
# Epoch 382 until 3800
# Epoch 383 until 3800
# Epoch 384 until 3800
# Epoch 385 until 3800
# Epoch 386 until 3800
# Epoch 387 until 3800
# Epoch 388 until 3800
# Epoch 389 until 3800
# Epoch 390 until 3800
# Epoch 391 until 3800
# Epoch 392 until 3800
# Epoch 393 until 3800
# Epoch 394 until 3800
# Epoch 395 until 3800
# Epoch 396 until 3800
# Epoch 397 until 3800
# Epoch 398 until 3800
# Epoch 399 until 3800
# Epoch 400 until 3800
# Epoch 401 until 3800
# Epoch 402 until 3800
# Epoch 403 until 3800
# Epoch 404 until 3800
# Epoch 405 until 3800
# Epoch 406 until 3800
# Epoch 407 until 3800
# Epoch 408 until 3800
# Epoch 409 until 3800
# Epoch 410 until 3800
# Epoch 411 until 3800
# Epoch 412 until 3800
# Epoch 413 until 3800
# Epoch 414 until 3800
# Epoch 415 until 3800
# Epoch 416 until 3800
# Epoch 417 until 3800
# Epoch 418 until 3800
# Epoch 419 until 3800
# Epoch 420 until 3800
# Epoch 421 until 3800
# Epoch 422 until 3800
# Epoch 423 until 3800
# Epoch 424 until 3800
# Epoch 425 until 3800
# Epoch 426 until 3800
# Epoch 427 until 3800
# Epoch 428 until 3800
# Epoch 429 until 3800
# Epoch 430 until 3800
# Epoch 431 until 3800
# Epoch 432 until 3800
# Epoch 433 until 3800
# Epoch 434 until 3800
# Epoch 435 until 3800
# Epoch 436 until 3800
# Epoch 437 until 3800
# Epoch 438 until 3800
# Epoch 439 until 3800
# Epoch 440 until 3800
# Epoch 441 until 3800
# Epoch 442 until 3800
# Epoch 443 until 3800
# Epoch 444 until 3800
# Epoch 445 until 3800
# Epoch 446 until 3800
# Epoch 447 until 3800
# Epoch 448 until 3800
# Epoch 449 until 3800
# Epoch 450 until 3800
# Epoch 451 until 3800
# Epoch 452 until 3800
# Epoch 453 until 3800
# Epoch 454 until 3800
# Epoch 455 until 3800
# Epoch 456 until 3800
# Epoch 457 until 3800
# Epoch 458 until 3800
# Epoch 459 until 3800
# Epoch 460 until 3800
# Epoch 461 until 3800
# Epoch 462 until 3800
# Epoch 463 until 3800
# Epoch 464 until 3800
# Epoch 465 until 3800
# Epoch 466 until 3800
# Epoch 467 until 3800
# Epoch 468 until 3800
# Epoch 469 until 3800
# Epoch 470 until 3800
# Epoch 471 until 3800
# Epoch 472 until 3800
# Epoch 473 until 3800
# Epoch 474 until 3800
# Epoch 475 until 3800
# Epoch 476 until 3800
# Epoch 477 until 3800
# Epoch 478 until 3800
# Epoch 479 until 3800
# Epoch 480 until 3800
# Epoch 481 until 3800
# Epoch 482 until 3800
# Epoch 483 until 3800
# Epoch 484 until 3800
# Epoch 485 until 3800
# Epoch 486 until 3800
# Epoch 487 until 3800
# Epoch 488 until 3800
# Epoch 489 until 3800
# Epoch 490 until 3800
# Epoch 491 until 3800
# Epoch 492 until 3800
# Epoch 493 until 3800
# Epoch 494 until 3800
# Epoch 495 until 3800
# Epoch 496 until 3800
# Epoch 497 until 3800
# Epoch 498 until 3800
# Epoch 499 until 3800
# Epoch 500 until 3800
# Epoch 501 until 3800
# Epoch 502 until 3800
# Epoch 503 until 3800
# Epoch 504 until 3800
# Epoch 505 until 3800
# Epoch 506 until 3800
# Epoch 507 until 3800
# Epoch 508 until 3800
# Epoch 509 until 3800
# Epoch 510 until 3800
# Epoch 511 until 3800
# Epoch 512 until 3800
# Epoch 513 until 3800
# Epoch 514 until 3800
# Epoch 515 until 3800
# Epoch 516 until 3800
# Epoch 517 until 3800
# Epoch 518 until 3800
# Epoch 519 until 3800
# Epoch 520 until 3800
# Epoch 521 until 3800
# Epoch 522 until 3800
# Epoch 523 until 3800
# Epoch 524 until 3800
# Epoch 525 until 3800
# Epoch 526 until 3800
# Epoch 527 until 3800
# Epoch 528 until 3800
# Epoch 529 until 3800
# Epoch 530 until 3800
# Epoch 531 until 3800
# Epoch 532 until 3800
# Epoch 533 until 3800
# Epoch 534 until 3800
# Epoch 535 until 3800
# Epoch 536 until 3800
# Epoch 537 until 3800
# Epoch 538 until 3800
# Epoch 539 until 3800
# Epoch 540 until 3800
# Epoch 541 until 3800
# Epoch 542 until 3800
# Epoch 543 until 3800
# Epoch 544 until 3800
# Epoch 545 until 3800
# Epoch 546 until 3800
# Epoch 547 until 3800
# Epoch 548 until 3800
# Epoch 549 until 3800
# Epoch 550 until 3800
# Epoch 551 until 3800
# Epoch 552 until 3800
# Epoch 553 until 3800
# Epoch 554 until 3800
# Epoch 555 until 3800
# Epoch 556 until 3800
# Epoch 557 until 3800
# Epoch 558 until 3800
# Epoch 559 until 3800
# Epoch 560 until 3800
# Epoch 561 until 3800
# Epoch 562 until 3800
# Epoch 563 until 3800
# Epoch 564 until 3800
# Epoch 565 until 3800
# Epoch 566 until 3800
# Epoch 567 until 3800
# Epoch 568 until 3800
# Epoch 569 until 3800
# Epoch 570 until 3800
# Epoch 571 until 3800
# Epoch 572 until 3800
# Epoch 573 until 3800
# Epoch 574 until 3800
# Epoch 575 until 3800
# Epoch 576 until 3800
# Epoch 577 until 3800
# Epoch 578 until 3800
# Epoch 579 until 3800
# Epoch 580 until 3800
# Epoch 581 until 3800
# Epoch 582 until 3800
# Epoch 583 until 3800
# Epoch 584 until 3800
# Epoch 585 until 3800
# Epoch 586 until 3800
# Epoch 587 until 3800
# Epoch 588 until 3800
# Epoch 589 until 3800
# Epoch 590 until 3800
# Epoch 591 until 3800
# Epoch 592 until 3800
# Epoch 593 until 3800
# Epoch 594 until 3800
# Epoch 595 until 3800
# Epoch 596 until 3800
# Epoch 597 until 3800
# Epoch 598 until 3800
# Epoch 599 until 3800
# Epoch 600 until 3800
# Epoch 601 until 3800
# Epoch 602 until 3800
# Epoch 603 until 3800
# Epoch 604 until 3800
# Epoch 605 until 3800
# Epoch 606 until 3800
# Epoch 607 until 3800
# Epoch 608 until 3800
# Epoch 609 until 3800
# Epoch 610 until 3800
# Epoch 611 until 3800
# Epoch 612 until 3800
# Epoch 613 until 3800
# Epoch 614 until 3800
# Epoch 615 until 3800
# Epoch 616 until 3800
# Epoch 617 until 3800
# Epoch 618 until 3800
# Epoch 619 until 3800
# Epoch 620 until 3800
# Epoch 621 until 3800
# Epoch 622 until 3800
# Epoch 623 until 3800
# Epoch 624 until 3800
# Epoch 625 until 3800
# Epoch 626 until 3800
# Epoch 627 until 3800
# Epoch 628 until 3800
# Epoch 629 until 3800
# Epoch 630 until 3800
# Epoch 631 until 3800
# Epoch 632 until 3800
# Epoch 633 until 3800
# Epoch 634 until 3800
# Epoch 635 until 3800
# Epoch 636 until 3800
# Epoch 637 until 3800
# Epoch 638 until 3800
# Epoch 639 until 3800
# Epoch 640 until 3800
# Epoch 641 until 3800
# Epoch 642 until 3800
# Epoch 643 until 3800
# Epoch 644 until 3800
# Epoch 645 until 3800
# Epoch 646 until 3800
# Epoch 647 until 3800
# Epoch 648 until 3800
# Epoch 649 until 3800
# Epoch 650 until 3800
# Epoch 651 until 3800
# Epoch 652 until 3800
# Epoch 653 until 3800
# Epoch 654 until 3800
# Epoch 655 until 3800
# Epoch 656 until 3800
# Epoch 657 until 3800
# Epoch 658 until 3800
# Epoch 659 until 3800
# Epoch 660 until 3800
# Epoch 661 until 3800
# Epoch 662 until 3800
# Epoch 663 until 3800
# Epoch 664 until 3800
# Epoch 665 until 3800
# Epoch 666 until 3800
# Epoch 667 until 3800
# Epoch 668 until 3800
# Epoch 669 until 3800
# Epoch 670 until 3800
# Epoch 671 until 3800
# Epoch 672 until 3800
# Epoch 673 until 3800
# Epoch 674 until 3800
# Epoch 675 until 3800
# Epoch 676 until 3800
# Epoch 677 until 3800
# Epoch 678 until 3800
# Epoch 679 until 3800
# Epoch 680 until 3800
# Epoch 681 until 3800
# Epoch 682 until 3800
# Epoch 683 until 3800
# Epoch 684 until 3800
# Epoch 685 until 3800
# Epoch 686 until 3800
# Epoch 687 until 3800
# Epoch 688 until 3800
# Epoch 689 until 3800
# Epoch 690 until 3800
# Epoch 691 until 3800
# Epoch 692 until 3800
# Epoch 693 until 3800
# Epoch 694 until 3800
# Epoch 695 until 3800
# Epoch 696 until 3800
# Epoch 697 until 3800
# Epoch 698 until 3800
# Epoch 699 until 3800
# Epoch 700 until 3800
# Epoch 701 until 3800
# Epoch 702 until 3800
# Epoch 703 until 3800
# Epoch 704 until 3800
# Epoch 705 until 3800
# Epoch 706 until 3800
# Epoch 707 until 3800
# Epoch 708 until 3800
# Epoch 709 until 3800
# Epoch 710 until 3800
# Epoch 711 until 3800
# Epoch 712 until 3800
# Epoch 713 until 3800
# Epoch 714 until 3800
# Epoch 715 until 3800
# Epoch 716 until 3800
# Epoch 717 until 3800
# Epoch 718 until 3800
# Epoch 719 until 3800
# Epoch 720 until 3800
# Epoch 721 until 3800
# Epoch 722 until 3800
# Epoch 723 until 3800
# Epoch 724 until 3800
# Epoch 725 until 3800
# Epoch 726 until 3800
# Epoch 727 until 3800
# Epoch 728 until 3800
# Epoch 729 until 3800
# Epoch 730 until 3800
# Epoch 731 until 3800
# Epoch 732 until 3800
# Epoch 733 until 3800
# Epoch 734 until 3800
# Epoch 735 until 3800
# Epoch 736 until 3800
# Epoch 737 until 3800
# Epoch 738 until 3800
# Epoch 739 until 3800
# Epoch 740 until 3800
# Epoch 741 until 3800
# Epoch 742 until 3800
# Epoch 743 until 3800
# Epoch 744 until 3800
# Epoch 745 until 3800
# Epoch 746 until 3800
# Epoch 747 until 3800
# Epoch 748 until 3800
# Epoch 749 until 3800
# Epoch 750 until 3800
# Epoch 751 until 3800
# Epoch 752 until 3800
# Epoch 753 until 3800
# Epoch 754 until 3800
# Epoch 755 until 3800
# Epoch 756 until 3800
# Epoch 757 until 3800
# Epoch 758 until 3800
# Epoch 759 until 3800
# Epoch 760 until 3800
# Epoch 761 until 3800
# Epoch 762 until 3800
# Epoch 763 until 3800
# Epoch 764 until 3800
# Epoch 765 until 3800
# Epoch 766 until 3800
# Epoch 767 until 3800
# Epoch 768 until 3800
# Epoch 769 until 3800
# Epoch 770 until 3800
# Epoch 771 until 3800
# Epoch 772 until 3800
# Epoch 773 until 3800
# Epoch 774 until 3800
# Epoch 775 until 3800
# Epoch 776 until 3800
# Epoch 777 until 3800
# Epoch 778 until 3800
# Epoch 779 until 3800
# Epoch 780 until 3800
# Epoch 781 until 3800
# Epoch 782 until 3800
# Epoch 783 until 3800
# Epoch 784 until 3800
# Epoch 785 until 3800
# Epoch 786 until 3800
# Epoch 787 until 3800
# Epoch 788 until 3800
# Epoch 789 until 3800
# Epoch 790 until 3800
# Epoch 791 until 3800
# Epoch 792 until 3800
# Epoch 793 until 3800
# Epoch 794 until 3800
# Epoch 795 until 3800
# Epoch 796 until 3800
# Epoch 797 until 3800
# Epoch 798 until 3800
# Epoch 799 until 3800
# Epoch 800 until 3800
# Epoch 801 until 3800
# Epoch 802 until 3800
# Epoch 803 until 3800
# Epoch 804 until 3800
# Epoch 805 until 3800
# Epoch 806 until 3800
# Epoch 807 until 3800
# Epoch 808 until 3800
# Epoch 809 until 3800
# Epoch 810 until 3800
# Epoch 811 until 3800
# Epoch 812 until 3800
# Epoch 813 until 3800
# Epoch 814 until 3800
# Epoch 815 until 3800
# Epoch 816 until 3800
# Epoch 817 until 3800
# Epoch 818 until 3800
# Epoch 819 until 3800
# Epoch 820 until 3800
# Epoch 821 until 3800
# Epoch 822 until 3800
# Epoch 823 until 3800
# Epoch 824 until 3800
# Epoch 825 until 3800
# Epoch 826 until 3800
# Epoch 827 until 3800
# Epoch 828 until 3800
# Epoch 829 until 3800
# Epoch 830 until 3800
# Epoch 831 until 3800
# Epoch 832 until 3800
# Epoch 833 until 3800
# Epoch 834 until 3800
# Epoch 835 until 3800
# Epoch 836 until 3800
# Epoch 837 until 3800
# Epoch 838 until 3800
# Epoch 839 until 3800
# Epoch 840 until 3800
# Epoch 841 until 3800
# Epoch 842 until 3800
# Epoch 843 until 3800
# Epoch 844 until 3800
# Epoch 845 until 3800
# Epoch 846 until 3800
# Epoch 847 until 3800
# Epoch 848 until 3800
# Epoch 849 until 3800
# Epoch 850 until 3800
# Epoch 851 until 3800
# Epoch 852 until 3800
# Epoch 853 until 3800
# Epoch 854 until 3800
# Epoch 855 until 3800
# Epoch 856 until 3800
# Epoch 857 until 3800
# Epoch 858 until 3800
# Epoch 859 until 3800
# Epoch 860 until 3800
# Epoch 861 until 3800
# Epoch 862 until 3800
# Epoch 863 until 3800
# Epoch 864 until 3800
# Epoch 865 until 3800
# Epoch 866 until 3800
# Epoch 867 until 3800
# Epoch 868 until 3800
# Epoch 869 until 3800
# Epoch 870 until 3800
# Epoch 871 until 3800
# Epoch 872 until 3800
# Epoch 873 until 3800
# Epoch 874 until 3800
# Epoch 875 until 3800
# Epoch 876 until 3800
# Epoch 877 until 3800
# Epoch 878 until 3800
# Epoch 879 until 3800
# Epoch 880 until 3800
# Epoch 881 until 3800
# Epoch 882 until 3800
# Epoch 883 until 3800
# Epoch 884 until 3800
# Epoch 885 until 3800
# Epoch 886 until 3800
# Epoch 887 until 3800
# Epoch 888 until 3800
# Epoch 889 until 3800
# Epoch 890 until 3800
# Epoch 891 until 3800
# Epoch 892 until 3800
# Epoch 893 until 3800
# Epoch 894 until 3800
# Epoch 895 until 3800
# Epoch 896 until 3800
# Epoch 897 until 3800
# Epoch 898 until 3800
# Epoch 899 until 3800
# Epoch 900 until 3800
# Epoch 901 until 3800
# Epoch 902 until 3800
# Epoch 903 until 3800
# Epoch 904 until 3800
# Epoch 905 until 3800
# Epoch 906 until 3800
# Epoch 907 until 3800
# Epoch 908 until 3800
# Epoch 909 until 3800
# Epoch 910 until 3800
# Epoch 911 until 3800
# Epoch 912 until 3800
# Epoch 913 until 3800
# Epoch 914 until 3800
# Epoch 915 until 3800
# Epoch 916 until 3800
# Epoch 917 until 3800
# Epoch 918 until 3800
# Epoch 919 until 3800
# Epoch 920 until 3800
# Epoch 921 until 3800
# Epoch 922 until 3800
# Epoch 923 until 3800
# Epoch 924 until 3800
# Epoch 925 until 3800
# Epoch 926 until 3800
# Epoch 927 until 3800
# Epoch 928 until 3800
# Epoch 929 until 3800
# Epoch 930 until 3800
# Epoch 931 until 3800
# Epoch 932 until 3800
# Epoch 933 until 3800
# Epoch 934 until 3800
# Epoch 935 until 3800
# Epoch 936 until 3800
# Epoch 937 until 3800
# Epoch 938 until 3800
# Epoch 939 until 3800
# Epoch 940 until 3800
# Epoch 941 until 3800
# Epoch 942 until 3800
# Epoch 943 until 3800
# Epoch 944 until 3800
# Epoch 945 until 3800
# Epoch 946 until 3800
# Epoch 947 until 3800
# Epoch 948 until 3800
# Epoch 949 until 3800
# Epoch 950 until 3800
# Epoch 951 until 3800
# Epoch 952 until 3800
# Epoch 953 until 3800
# Epoch 954 until 3800
# Epoch 955 until 3800
# Epoch 956 until 3800
# Epoch 957 until 3800
# Epoch 958 until 3800
# Epoch 959 until 3800
# Epoch 960 until 3800
# Epoch 961 until 3800
# Epoch 962 until 3800
# Epoch 963 until 3800
# Epoch 964 until 3800
# Epoch 965 until 3800
# Epoch 966 until 3800
# Epoch 967 until 3800
# Epoch 968 until 3800
# Epoch 969 until 3800
# Epoch 970 until 3800
# Epoch 971 until 3800
# Epoch 972 until 3800
# Epoch 973 until 3800
# Epoch 974 until 3800
# Epoch 975 until 3800
# Epoch 976 until 3800
# Epoch 977 until 3800
# Epoch 978 until 3800
# Epoch 979 until 3800
# Epoch 980 until 3800
# Epoch 981 until 3800
# Epoch 982 until 3800
# Epoch 983 until 3800
# Epoch 984 until 3800
# Epoch 985 until 3800
# Epoch 986 until 3800
# Epoch 987 until 3800
# Epoch 988 until 3800
# Epoch 989 until 3800
# Epoch 990 until 3800
# Epoch 991 until 3800
# Epoch 992 until 3800
# Epoch 993 until 3800
# Epoch 994 until 3800
# Epoch 995 until 3800
# Epoch 996 until 3800
# Epoch 997 until 3800
# Epoch 998 until 3800
# Epoch 999 until 3800
# Epoch 1000 until 3800
# Epoch 1001 until 3800
# Epoch 1002 until 3800
# Epoch 1003 until 3800
# Epoch 1004 until 3800
# Epoch 1005 until 3800
# Epoch 1006 until 3800
# Epoch 1007 until 3800
# Epoch 1008 until 3800
# Epoch 1009 until 3800
# Epoch 1010 until 3800
# Epoch 1011 until 3800
# Epoch 1012 until 3800
# Epoch 1013 until 3800
# Epoch 1014 until 3800
# Epoch 1015 until 3800
# Epoch 1016 until 3800
# Epoch 1017 until 3800
# Epoch 1018 until 3800
# Epoch 1019 until 3800
# Epoch 1020 until 3800
# Epoch 1021 until 3800
# Epoch 1022 until 3800
# Epoch 1023 until 3800
# Epoch 1024 until 3800
# Epoch 1025 until 3800
# Epoch 1026 until 3800
# Epoch 1027 until 3800
# Epoch 1028 until 3800
# Epoch 1029 until 3800
# Epoch 1030 until 3800
# Epoch 1031 until 3800
# Epoch 1032 until 3800
# Epoch 1033 until 3800
# Epoch 1034 until 3800
# Epoch 1035 until 3800
# Epoch 1036 until 3800
# Epoch 1037 until 3800
# Epoch 1038 until 3800
# Epoch 1039 until 3800
# Epoch 1040 until 3800
# Epoch 1041 until 3800
# Epoch 1042 until 3800
# Epoch 1043 until 3800
# Epoch 1044 until 3800
# Epoch 2151 until 3800
# Epoch 2152 until 3800
# Epoch 2153 until 3800
# Epoch 2154 until 3800
# Epoch 2155 until 3800
# Epoch 2156 until 3800
# Epoch 2157 until 3800
# Epoch 2158 until 3800
# Epoch 2159 until 3800
# Epoch 2160 until 3800
# Epoch 2161 until 3800
# Epoch 2162 until 3800
# Epoch 2163 until 3800
# Epoch 2164 until 3800
# Epoch 2165 until 3800
# Epoch 2166 until 3800
# Epoch 2167 until 3800
# Epoch 2168 until 3800
# Epoch 2169 until 3800
# Epoch 2170 until 3800
# Epoch 2171 until 3800
# Epoch 2172 until 3800
# Epoch 2173 until 3800
# Epoch 2174 until 3800
# Epoch 2175 until 3800
# Epoch 2176 until 3800
# Epoch 2177 until 3800
# Epoch 2178 until 3800
# Epoch 2179 until 3800
# Epoch 2180 until 3800
# Epoch 2181 until 3800
# Epoch 2182 until 3800
# Epoch 2183 until 3800
# Epoch 2184 until 3800
# Epoch 2185 until 3800
# Epoch 2186 until 3800
# Epoch 2187 until 3800
# Epoch 2188 until 3800
# Epoch 2189 until 3800
# Epoch 2190 until 3800
# Epoch 2191 until 3800
# Epoch 2192 until 3800
# Epoch 2193 until 3800
# Epoch 2194 until 3800
# Epoch 2195 until 3800
# Epoch 2196 until 3800
# Epoch 2197 until 3800
# Epoch 2198 until 3800
# Epoch 2199 until 3800
# Epoch 2200 until 3800
# Epoch 2201 until 3800
# Epoch 2202 until 3800
# Epoch 2203 until 3800
# Epoch 2204 until 3800
# Epoch 2205 until 3800
# Epoch 2206 until 3800
# Epoch 2207 until 3800
# Epoch 2208 until 3800
# Epoch 2209 until 3800
# Epoch 2210 until 3800
# Epoch 2211 until 3800
# Epoch 2212 until 3800
# Epoch 2213 until 3800
# Epoch 2214 until 3800
# Epoch 2215 until 3800
# Epoch 2216 until 3800
# Epoch 2217 until 3800
# Epoch 2218 until 3800
# Epoch 2219 until 3800
# Epoch 2220 until 3800
# Epoch 2221 until 3800
# Epoch 2222 until 3800
# Epoch 2223 until 3800
# Epoch 2224 until 3800
# Epoch 2225 until 3800
# Epoch 2226 until 3800
# Epoch 2227 until 3800
# Epoch 2228 until 3800
# Epoch 2229 until 3800
# Epoch 2230 until 3800
# Epoch 2231 until 3800
# ...
# Epoch 3073 until 3800
# Epoch 3074 until 3800
# Epoch 3075 until 3800
# Epoch 3076 until 3800
# Epoch 3077 until 3800
# Epoch 3078 until 3800
# Epoch 3079 until 3800
# Epoch 3080 until 3800
# Epoch 3081 until 3800
# Epoch 3082 until 3800
# Epoch 3083 until 3800
# Epoch 3084 until 3800
# Epoch 3085 until 3800
# Epoch 3086 until 3800
# Epoch 3087 until 3800
# Epoch 3088 until 3800
# Epoch 3089 until 3800
# Epoch 3090 until 3800
# Epoch 3091 until 3800
# Epoch 3092 until 3800
# Epoch 3093 until 3800
# Epoch 3094 until 3800
# Epoch 3095 until 3800
# Epoch 3096 until 3800
# Epoch 3097 until 3800
# Epoch 3098 until 3800
# Epoch 3099 until 3800
# Epoch 3100 until 3800
# Epoch 3101 until 3800
# Epoch 3102 until 3800
# Epoch 3103 until 3800
# Epoch 3104 until 3800
# Epoch 3105 until 3800
# Epoch 3106 until 3800
# Epoch 3107 until 3800
# Epoch 3108 until 3800
# Epoch 3109 until 3800
# Epoch 3110 until 3800
# Epoch 3111 until 3800
# Epoch 3112 until 3800
# Epoch 3113 until 3800
# Epoch 3114 until 3800
# Epoch 3115 until 3800
# Epoch 3116 until 3800
# Epoch 3117 until 3800
# Epoch 3118 until 3800
# Epoch 3119 until 3800
# Epoch 3120 until 3800
# Epoch 3121 until 3800
# Epoch 3122 until 3800
# Epoch 3123 until 3800
# Epoch 3124 until 3800
# Epoch 3125 until 3800
# Epoch 3126 until 3800
# Epoch 3127 until 3800
# Epoch 3128 until 3800
# Epoch 3129 until 3800
# Epoch 3130 until 3800
# Epoch 3131 until 3800
# Epoch 3132 until 3800
# Epoch 3133 until 3800
# Epoch 3134 until 3800
# Epoch 3135 until 3800
# Epoch 3136 until 3800
# Epoch 3137 until 3800
# Epoch 3138 until 3800
# Epoch 3139 until 3800
# Epoch 3140 until 3800
# Epoch 3141 until 3800
# Epoch 3142 until 3800
# Epoch 3143 until 3800
# Epoch 3144 until 3800
# Epoch 3145 until 3800
# Epoch 3146 until 3800
# Epoch 3147 until 3800
# Epoch 3148 until 3800
# Epoch 3149 until 3800
# Epoch 3150 until 3800
# Epoch 3151 until 3800
# Epoch 3152 until 3800
# Epoch 3153 until 3800
# Epoch 3154 until 3800
# Epoch 3155 until 3800
# Epoch 3156 until 3800
# Epoch 3157 until 3800
# Epoch 3158 until 3800
# Epoch 3159 until 3800
# Epoch 3160 until 3800
# Epoch 3161 until 3800
# Epoch 3162 until 3800
# Epoch 3163 until 3800
# Epoch 3164 until 3800
# Epoch 3165 until 3800
# Epoch 3166 until 3800
# Epoch 3167 until 3800
# Epoch 3168 until 3800
# Epoch 3169 until 3800
# Epoch 3170 until 3800
# Epoch 3171 until 3800
# Epoch 3172 until 3800
# Epoch 3173 until 3800
# Epoch 3174 until 3800
# Epoch 3175 until 3800
# Epoch 3176 until 3800
# Epoch 3177 until 3800
# Epoch 3178 until 3800
# Epoch 3179 until 3800
# Epoch 3180 until 3800
# Epoch 3181 until 3800
# Epoch 3182 until 3800
# Epoch 3183 until 3800
# Epoch 3184 until 3800
# Epoch 3185 until 3800
# Epoch 3186 until 3800
# Epoch 3187 until 3800
# Epoch 3188 until 3800
# Epoch 3189 until 3800
# Epoch 3190 until 3800
# Epoch 3191 until 3800
# Epoch 3192 until 3800
# Epoch 3193 until 3800
# Epoch 3194 until 3800
# Epoch 3195 until 3800
# Epoch 3196 until 3800
# Epoch 3197 until 3800
# Epoch 3198 until 3800
# Epoch 3199 until 3800
# Epoch 3200 until 3800
# Epoch 3201 until 3800
# Epoch 3202 until 3800
# Epoch 3203 until 3800
# Epoch 3204 until 3800
# Epoch 3205 until 3800
# Epoch 3206 until 3800
# Epoch 3207 until 3800
# Epoch 3208 until 3800
# Epoch 3209 until 3800
# Epoch 3210 until 3800
# Epoch 3211 until 3800
# Epoch 3212 until 3800
# Epoch 3213 until 3800
# Epoch 3214 until 3800
# Epoch 3215 until 3800
# Epoch 3216 until 3800
# Epoch 3217 until 3800
# Epoch 3218 until 3800
# Epoch 3219 until 3800
# Epoch 3220 until 3800
# Epoch 3221 until 3800
# Epoch 3222 until 3800
# Epoch 3223 until 3800
# Epoch 3224 until 3800
# Epoch 3225 until 3800
# Epoch 3226 until 3800
# Epoch 3227 until 3800
# Epoch 3228 until 3800
# Epoch 3229 until 3800
# Epoch 3230 until 3800
# Epoch 3231 until 3800
# Epoch 3232 until 3800
# Epoch 3233 until 3800
# Epoch 3234 until 3800
# Epoch 3235 until 3800
# Epoch 3236 until 3800
# Epoch 3237 until 3800
# Epoch 3238 until 3800
# Epoch 3239 until 3800
# Epoch 3240 until 3800
# Epoch 3241 until 3800
# Epoch 3242 until 3800
# Epoch 3243 until 3800
# Epoch 3244 until 3800
# Epoch 3245 until 3800
# Epoch 3246 until 3800
# Epoch 3247 until 3800
# Epoch 3248 until 3800
# Epoch 3249 until 3800
# Epoch 3250 until 3800
# Epoch 3251 until 3800
# Epoch 3252 until 3800
# Epoch 3253 until 3800
# Epoch 3254 until 3800
# Epoch 3255 until 3800
# Epoch 3256 until 3800
# Epoch 3257 until 3800
# Epoch 3258 until 3800
# Epoch 3259 until 3800
# Epoch 3260 until 3800
# Epoch 3261 until 3800
# Epoch 3262 until 3800
# Epoch 3263 until 3800
# Epoch 3264 until 3800
# Epoch 3265 until 3800
# Epoch 3266 until 3800
# Epoch 3267 until 3800
# Epoch 3268 until 3800
# Epoch 3269 until 3800
# Epoch 3270 until 3800
# Epoch 3271 until 3800
# Epoch 3272 until 3800
# Epoch 3273 until 3800
# Epoch 3274 until 3800
# Epoch 3275 until 3800
# Epoch 3276 until 3800
# Epoch 3277 until 3800
# Epoch 3278 until 3800
# Epoch 3279 until 3800
# Epoch 3280 until 3800
# Epoch 3281 until 3800
# Epoch 3282 until 3800
# Epoch 3283 until 3800
# Epoch 3284 until 3800
# Epoch 3285 until 3800
# Epoch 3286 until 3800
# Epoch 3287 until 3800
# Epoch 3288 until 3800
# Epoch 3289 until 3800
# Epoch 3290 until 3800
# Epoch 3291 until 3800
# Epoch 3292 until 3800
# Epoch 3293 until 3800
# Epoch 3294 until 3800
# Epoch 3295 until 3800
# Epoch 3296 until 3800
# Epoch 3297 until 3800
# Epoch 3298 until 3800
# Epoch 3299 until 3800
# Epoch 3300 until 3800
# Epoch 3301 until 3800
# Epoch 3302 until 3800
# Epoch 3303 until 3800
# Epoch 3304 until 3800
# Epoch 3305 until 3800
# Epoch 3306 until 3800
# Epoch 3307 until 3800
# Epoch 3308 until 3800
# Epoch 3309 until 3800
# Epoch 3310 until 3800
# Epoch 3311 until 3800
# Epoch 3312 until 3800
# Epoch 3313 until 3800
# Epoch 3314 until 3800
# Epoch 3315 until 3800
# Epoch 3316 until 3800
# Epoch 3317 until 3800
# Epoch 3318 until 3800
# Epoch 3319 until 3800
# Epoch 3320 until 3800
# Epoch 3321 until 3800
# Epoch 3322 until 3800
# Epoch 3323 until 3800
# Epoch 3324 until 3800
# Epoch 3325 until 3800
# Epoch 3326 until 3800
# Epoch 3327 until 3800
# Epoch 3328 until 3800
# Epoch 3329 until 3800
# Epoch 3330 until 3800
# Epoch 3331 until 3800
# Epoch 3332 until 3800
# Epoch 3333 until 3800
# Epoch 3334 until 3800
# Epoch 3335 until 3800
# Epoch 3336 until 3800
# Epoch 3337 until 3800
# Epoch 3338 until 3800
# Epoch 3339 until 3800
# Epoch 3340 until 3800
# Epoch 3341 until 3800
# Epoch 3342 until 3800
# Epoch 3343 until 3800
# Epoch 3344 until 3800
# Epoch 3345 until 3800
# Epoch 3346 until 3800
# Epoch 3347 until 3800
# Epoch 3348 until 3800
# Epoch 3349 until 3800
# Epoch 3350 until 3800
# Epoch 3351 until 3800
# Epoch 3352 until 3800
# Epoch 3353 until 3800
# Epoch 3354 until 3800
# Epoch 3355 until 3800
# Epoch 3356 until 3800
# Epoch 3357 until 3800
# Epoch 3358 until 3800
# Epoch 3359 until 3800
# Epoch 3360 until 3800
# Epoch 3361 until 3800
# Epoch 3362 until 3800
# Epoch 3363 until 3800
# Epoch 3364 until 3800
# Epoch 3365 until 3800
# Epoch 3366 until 3800
# Epoch 3367 until 3800
# Epoch 3368 until 3800
# Epoch 3369 until 3800
# Epoch 3370 until 3800
# Epoch 3371 until 3800
# Epoch 3372 until 3800
# Epoch 3373 until 3800
# Epoch 3374 until 3800
# Epoch 3375 until 3800
# Epoch 3376 until 3800
# Epoch 3377 until 3800
# Epoch 3378 until 3800
# Epoch 3379 until 3800
# Epoch 3380 until 3800
# Epoch 3381 until 3800
# Epoch 3382 until 3800
# Epoch 3383 until 3800
# Epoch 3384 until 3800
# Epoch 3385 until 3800
# Epoch 3386 until 3800
# Epoch 3387 until 3800
# Epoch 3388 until 3800
# Epoch 3389 until 3800
# Epoch 3390 until 3800
# Epoch 3391 until 3800
# Epoch 3392 until 3800
# Epoch 3393 until 3800
# Epoch 3394 until 3800
# Epoch 3395 until 3800
# Epoch 3396 until 3800
# Epoch 3397 until 3800
# Epoch 3398 until 3800
# Epoch 3399 until 3800
# Epoch 3400 until 3800
# Epoch 3401 until 3800
# Epoch 3402 until 3800
# Epoch 3403 until 3800
# Epoch 3404 until 3800
# Epoch 3405 until 3800
# Epoch 3406 until 3800
# Epoch 3407 until 3800
# Epoch 3408 until 3800
# Epoch 3409 until 3800
# Epoch 3410 until 3800
# Epoch 3411 until 3800
# Epoch 3412 until 3800
# Epoch 3413 until 3800
# Epoch 3414 until 3800
# Epoch 3415 until 3800
# Epoch 3416 until 3800
# Epoch 3417 until 3800
# Epoch 3418 until 3800
# Epoch 3419 until 3800
# Epoch 3420 until 3800
# Epoch 3421 until 3800
# Epoch 3422 until 3800
# Epoch 3423 until 3800
# Epoch 3424 until 3800
# Epoch 3425 until 3800
# Epoch 3426 until 3800
# Epoch 3427 until 3800
# Epoch 3428 until 3800
# Epoch 3429 until 3800
# Epoch 3430 until 3800
# Epoch 3431 until 3800
# Epoch 3432 until 3800
# Epoch 3433 until 3800
# Epoch 3434 until 3800
# Epoch 3435 until 3800
# Epoch 3436 until 3800
# Epoch 3437 until 3800
# Epoch 3438 until 3800
# Epoch 3439 until 3800
# Epoch 3440 until 3800
# Epoch 3441 until 3800
# Epoch 3442 until 3800
# Epoch 3443 until 3800
# Epoch 3444 until 3800
# Epoch 3445 until 3800
# Epoch 3446 until 3800
# Epoch 3447 until 3800
# Epoch 3448 until 3800
# Epoch 3449 until 3800
# Epoch 3450 until 3800
# Epoch 3451 until 3800
# Epoch 3452 until 3800
# Epoch 3453 until 3800
# Epoch 3454 until 3800
# Epoch 3455 until 3800
# Epoch 3456 until 3800
# Epoch 3457 until 3800
# Epoch 3458 until 3800
# Epoch 3459 until 3800
# Epoch 3460 until 3800
# Epoch 3461 until 3800
# Epoch 3462 until 3800
# Epoch 3463 until 3800
# Epoch 3464 until 3800
# Epoch 3465 until 3800
# Epoch 3466 until 3800
# Epoch 3467 until 3800
# Epoch 3468 until 3800
# Epoch 3469 until 3800
# Epoch 3470 until 3800
# Epoch 3471 until 3800
# Epoch 3472 until 3800
# Epoch 3473 until 3800
# Epoch 3474 until 3800
# Epoch 3475 until 3800
# Epoch 3476 until 3800
# Epoch 3477 until 3800
# Epoch 3478 until 3800
# Epoch 3479 until 3800
# Epoch 3480 until 3800
# Epoch 3481 until 3800
# Epoch 3482 until 3800
# Epoch 3483 until 3800
# Epoch 3484 until 3800
# Epoch 3485 until 3800
# Epoch 3486 until 3800
# Epoch 3487 until 3800
# Epoch 3488 until 3800
# Epoch 3489 until 3800
# Epoch 3490 until 3800
# Epoch 3491 until 3800
# Epoch 3492 until 3800
# Epoch 3493 until 3800
# Epoch 3494 until 3800
# Epoch 3495 until 3800
# Epoch 3496 until 3800
# Epoch 3497 until 3800
# Epoch 3498 until 3800
# Epoch 3499 until 3800
# Epoch 3500 until 3800
# Epoch 3501 until 3800
# Epoch 3502 until 3800
# Epoch 3503 until 3800
# Epoch 3504 until 3800
# Epoch 3505 until 3800
# Epoch 3506 until 3800
# Epoch 3507 until 3800
# Epoch 3508 until 3800
# Epoch 3509 until 3800
# Epoch 3510 until 3800
# Epoch 3511 until 3800
# Epoch 3512 until 3800
# Epoch 3513 until 3800
# Epoch 3514 until 3800
# Epoch 3515 until 3800
# Epoch 3516 until 3800
# Epoch 3517 until 3800
# Epoch 3518 until 3800
# Epoch 3519 until 3800
# Epoch 3520 until 3800
# Epoch 3521 until 3800
# Epoch 3522 until 3800
# Epoch 3523 until 3800
# Epoch 3524 until 3800
# Epoch 3525 until 3800
# Epoch 3526 until 3800
# Epoch 3527 until 3800
# Epoch 3528 until 3800
# Epoch 3529 until 3800
# Epoch 3530 until 3800
# Epoch 3531 until 3800
# Epoch 3532 until 3800
# Epoch 3533 until 3800
# Epoch 3534 until 3800
# Epoch 3535 until 3800
# Epoch 3536 until 3800
# Epoch 3537 until 3800
# Epoch 3538 until 3800
# Epoch 3539 until 3800
# Epoch 3540 until 3800
# Epoch 3541 until 3800
# Epoch 3542 until 3800
# Epoch 3543 until 3800
# Epoch 3544 until 3800
# Epoch 3545 until 3800
# Epoch 3546 until 3800
# Epoch 3547 until 3800
# Epoch 3548 until 3800
# Epoch 3549 until 3800
# Epoch 3550 until 3800
# Epoch 3551 until 3800
# Epoch 3552 until 3800
# Epoch 3553 until 3800
# Epoch 3554 until 3800
# Epoch 3555 until 3800
# Epoch 3556 until 3800
# Epoch 3557 until 3800
# Epoch 3558 until 3800
# Epoch 3559 until 3800
# Epoch 3560 until 3800
# Epoch 3561 until 3800
# Epoch 3562 until 3800
# Epoch 3563 until 3800
# Epoch 3564 until 3800
# Epoch 3565 until 3800
# Epoch 3566 until 3800
# Epoch 3567 until 3800
# Epoch 3568 until 3800
# Epoch 3569 until 3800
# Epoch 3570 until 3800
# Epoch 3571 until 3800
# Epoch 3572 until 3800
# Epoch 3573 until 3800
# Epoch 3574 until 3800
# Epoch 3575 until 3800
# Epoch 3576 until 3800
# Epoch 3577 until 3800
# Epoch 3578 until 3800
# Epoch 3579 until 3800
# Epoch 3580 until 3800
# Epoch 3581 until 3800
# Epoch 3582 until 3800
# Epoch 3583 until 3800
# Epoch 3584 until 3800
# Epoch 3585 until 3800
# Epoch 3586 until 3800
# Epoch 3587 until 3800
# Epoch 3588 until 3800
# Epoch 3589 until 3800
# Epoch 3590 until 3800
# Epoch 3591 until 3800
# Epoch 3592 until 3800
# Epoch 3593 until 3800
# Epoch 3594 until 3800
# Epoch 3595 until 3800
# Epoch 3596 until 3800
# Epoch 3597 until 3800
# Epoch 3598 until 3800
# Epoch 3599 until 3800
# Epoch 3600 until 3800
# Epoch 3601 until 3800
# Epoch 3602 until 3800
# Epoch 3603 until 3800
# Epoch 3604 until 3800
# Epoch 3605 until 3800
# Epoch 3606 until 3800
# Epoch 3607 until 3800
# Epoch 3608 until 3800
# Epoch 3609 until 3800
# Epoch 3610 until 3800
# Epoch 3611 until 3800
# Epoch 3612 until 3800
# Epoch 3613 until 3800
# Epoch 3614 until 3800
# Epoch 3615 until 3800
# Epoch 3616 until 3800
# Epoch 3617 until 3800
# Epoch 3618 until 3800
# Epoch 3619 until 3800
# Epoch 3620 until 3800
# Epoch 3621 until 3800
# Epoch 3622 until 3800
# Epoch 3623 until 3800
# Epoch 3624 until 3800
# Epoch 3625 until 3800
# Epoch 3626 until 3800
# Epoch 3627 until 3800
# Epoch 3628 until 3800
# Epoch 3629 until 3800
# Epoch 3630 until 3800
# Epoch 3631 until 3800
# Epoch 3632 until 3800
# Epoch 3633 until 3800
# Epoch 3634 until 3800
# Epoch 3635 until 3800
# Epoch 3636 until 3800
# Epoch 3637 until 3800
# Epoch 3638 until 3800
# Epoch 3639 until 3800
# Epoch 3640 until 3800
# Epoch 3641 until 3800
# Epoch 3642 until 3800
# Epoch 3643 until 3800
# Epoch 3644 until 3800
# Epoch 3645 until 3800
# Epoch 3646 until 3800
# Epoch 3647 until 3800
# Epoch 3648 until 3800
# Epoch 3649 until 3800
# Epoch 3650 until 3800
# Epoch 3651 until 3800
# Epoch 3652 until 3800
# Epoch 3653 until 3800
# Epoch 3654 until 3800
# Epoch 3655 until 3800
# Epoch 3656 until 3800
# Epoch 3657 until 3800
# Epoch 3658 until 3800
# Epoch 3659 until 3800
# Epoch 3660 until 3800
# Epoch 3661 until 3800
# Epoch 3662 until 3800
# Epoch 3663 until 3800
# Epoch 3664 until 3800
# Epoch 3665 until 3800
# Epoch 3666 until 3800
# Epoch 3667 until 3800
# Epoch 3668 until 3800
# Epoch 3669 until 3800
# Epoch 3670 until 3800
# Epoch 3671 until 3800
# Epoch 3672 until 3800
# Epoch 3673 until 3800
# Epoch 3674 until 3800
# Epoch 3675 until 3800
# Epoch 3676 until 3800
# Epoch 3677 until 3800
# Epoch 3678 until 3800
# Epoch 3679 until 3800
# Epoch 3680 until 3800
# Epoch 3681 until 3800
# Epoch 3682 until 3800
# Epoch 3683 until 3800
# Epoch 3684 until 3800
# Epoch 3685 until 3800
# Epoch 3686 until 3800
# Epoch 3687 until 3800
# Epoch 3688 until 3800
# Epoch 3689 until 3800
# Epoch 3690 until 3800
# Epoch 3691 until 3800
# Epoch 3692 until 3800
# Epoch 3693 until 3800
# Epoch 3694 until 3800
# Epoch 3695 until 3800
# Epoch 3696 until 3800
# Epoch 3697 until 3800
# Epoch 3698 until 3800
# Epoch 3699 until 3800
# Epoch 3700 until 3800
# Epoch 3701 until 3800
# Epoch 3702 until 3800
# Epoch 3703 until 3800
# Epoch 3704 until 3800
# Epoch 3705 until 3800
# Epoch 3706 until 3800
# Epoch 3707 until 3800
# Epoch 3708 until 3800
# Epoch 3709 until 3800
# Epoch 3710 until 3800
# Epoch 3711 until 3800
# Epoch 3712 until 3800
# Epoch 3713 until 3800
# Epoch 3714 until 3800
# Epoch 3715 until 3800
# Epoch 3716 until 3800
# Epoch 3717 until 3800
# Epoch 3718 until 3800
# Epoch 3719 until 3800
# Epoch 3720 until 3800
# Epoch 3721 until 3800
# Epoch 3722 until 3800
# Epoch 3723 until 3800
# Epoch 3724 until 3800
# Epoch 3725 until 3800
# Epoch 3726 until 3800
# Epoch 3727 until 3800
# Epoch 3728 until 3800
# Epoch 3729 until 3800
# Epoch 3730 until 3800
# Epoch 3731 until 3800
# Epoch 3732 until 3800
# Epoch 3733 until 3800
# Epoch 3734 until 3800
# Epoch 3735 until 3800
# Epoch 3736 until 3800
# Epoch 3737 until 3800
# Epoch 3738 until 3800
# Epoch 3739 until 3800
# Epoch 3740 until 3800
# Epoch 3741 until 3800
# Epoch 3742 until 3800
# Epoch 3743 until 3800
# Epoch 3744 until 3800
# Epoch 3745 until 3800
# Epoch 3746 until 3800
# Epoch 3747 until 3800
# Epoch 3748 until 3800
# Epoch 3749 until 3800
# Epoch 3750 until 3800
# Epoch 3751 until 3800
# Epoch 3752 until 3800
# Epoch 3753 until 3800
# Epoch 3754 until 3800
# Epoch 3755 until 3800
# Epoch 3756 until 3800
# Epoch 3757 until 3800
# Epoch 3758 until 3800
# Epoch 3759 until 3800
# Epoch 3760 until 3800
# Epoch 3761 until 3800
# Epoch 3762 until 3800
# Epoch 3763 until 3800
# Epoch 3764 until 3800
# Epoch 3765 until 3800
# Epoch 3766 until 3800
# Epoch 3767 until 3800
# Epoch 3768 until 3800
# Epoch 3769 until 3800
# Epoch 3770 until 3800
# Epoch 3771 until 3800
# Epoch 3772 until 3800
# Epoch 3773 until 3800
# Epoch 3774 until 3800
# Epoch 3775 until 3800
# Epoch 3776 until 3800
# Epoch 3777 until 3800
# Epoch 3778 until 3800
# Epoch 3779 until 3800
# Epoch 3780 until 3800
# Epoch 3781 until 3800
# Epoch 3782 until 3800
# Epoch 3783 until 3800
# Epoch 3784 until 3800
# Epoch 3785 until 3800
# Epoch 3786 until 3800
# Epoch 3787 until 3800
# Epoch 3788 until 3800
# Epoch 3789 until 3800
# Epoch 3790 until 3800
# Epoch 3791 until 3800
# Epoch 3792 until 3800
# Epoch 3793 until 3800
# Epoch 3794 until 3800
# Epoch 3795 until 3800
# Epoch 3796 until 3800
# Epoch 3797 until 3800
# Epoch 3798 until 3800
# Epoch 3799 until 3800

# %%
import helper
helper.evaluate_model(model,val_loader,"pytorch","pytorch",0)
# Out:
# {'iteration': 0,
#  'name': 'pytorch->pytorch',
#  'accuracy': 0.8959731543624161,
#  'precision': 0.7872340425531915,
#  'recall': 0.6379310344827587,
#  'f1': 0.7047619047619048,
#  'auc': 0.8880747126436781}

# %%
torch.save(model, 'models/base_data_tensorflow.pt')

# %% [markdown]
# # Prediction on Different Data Set

# %%
model_base = torch.load('models/base_data_tensorflow.pt')
# Out:
# /var/folders/zp/f7z3n2sd0ygb8_hfzm0lbzb40000gn/T/ipykernel_14313/1857705174.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_base = torch.load('models/base_data_tensorflow.pt')

# %%
inference_dataset=TextDataset.TextDatasetTFIDF("datasets/caffe.csv")
inference_loader = DataLoader(inference_dataset, batch_size=32, shuffle=False)
# Out:
# Preprocessed DataFrame:
#                                                    text  sentiment
# 9    unable to reproduce accuracy of bvlc-alexnet. ...          1
# 267  osx: abs not defined absval_layer. When compil...          0
# 143  cafe_intsall.caffe 36 error. I am trying caffe...          0
# 212   undefined reference to `lzma_index_end@XZ_5.0...          0
# 227  Dimension mismatch training with my own model ...          0

# %%
len(inference_loader)
# Out:
# 9

# %%
helper.evaluate_model(model_base,inference_loader,"pytorch","keras",0)
# Out:
# {'iteration': 0,
#  'name': 'pytorch->keras',
#  'accuracy': 0.8006993006993007,
#  'precision': 0.125,
#  'recall': 0.12121212121212122,
#  'f1': 0.12307692307692308,
#  'auc': 0.5509641873278237}

# %% [markdown]
# # Trying Tent on Title Body Caffe

# %%
import tent
import TextDataset
import importlib
# import batch_data_loader
importlib.reload(TextDataset)  
importlib.reload(tent)
# Out:
# <module 'tent' from '/Volumes/Dwika/ISE/ISE-solution/lab1/tent.py'>

# %%
result=tent.TentLayerNorm(model_base,inference_loader,"pytorch","keras",1)
result
# Out:
# Here
# Adapting with Tent: 100%|██████████| 9/9 [00:00<00:00, 326.04it/s]
# {'iteration': 1,
#  'name': 'pytorch->keras',
#  'accuracy': 0.8041958041958042,
#  'precision': 0.12903225806451613,
#  'recall': 0.12121212121212122,
#  'f1': 0.125,
#  'auc': 0.5544376572044556}
